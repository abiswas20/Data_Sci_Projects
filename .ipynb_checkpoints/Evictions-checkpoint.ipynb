# %% [markdown]
# ### In Progress

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
import json # library to handle JSON files
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import folium # map rendering library
from functools import reduce
import scipy

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
df1=pd.read_csv('Evictions.csv')

# %%
df1.head()
# Out:
#   COURT_INDEX_NUMBER  DOCKET_NUMBER          EVICTION_ADDRESS  \
# 0           62712/18          19077         80-15 41ST AVENUE
# 1           54221/17         332335       31 EAST 31ST STREET
# 2          B42362/19         117551  1605 METROPOLITAN AVENUE
# 3          K85736/19         102339         1236 UNION STREET
# 4           24576/17           2778           1085 NELSON AVE
#
#   EVICTION_APT_NUM EXECUTED_DATE MARSHAL_FIRST_NAME MARSHAL_LAST_NAME  \
# 0              215    09/20/2018             Edward             Guida
# 1           GROUND    09/19/2017             Thomas               Bia
# 2               9H    02/26/2020            Darlene            Barone
# 3               3D    02/26/2020             Ileana            Rivera
# 4               1A    12/13/2017              Vadim       Barbarovich
#
#   RESIDENTIAL_COMMERCIAL_IND    BOROUGH  EVICTION_ZIP
# 0                Residential     QUEENS         11373
# 1                 Commercial  MANHATTAN         10016
# 2                Residential      BRONX         10462
# 3                Residential   BROOKLYN         11225
# 4                Residential      BRONX         10452

# %% [markdown]
# Let's see the date range for the data.

# %%
df1['EXECUTED_DATE'].min()
# Out:
# '01/02/2018'

# %%
df1['EXECUTED_DATE'].max()
# Out:
# '12/31/2019'

# %% [markdown]
# This appears to be two years worth of data.

# %%
df1.head()
# Out:
#   COURT_INDEX_NUMBER  DOCKET_NUMBER          EVICTION_ADDRESS  \
# 0           62712/18          19077         80-15 41ST AVENUE
# 1           54221/17         332335       31 EAST 31ST STREET
# 2          B42362/19         117551  1605 METROPOLITAN AVENUE
# 3          K85736/19         102339         1236 UNION STREET
# 4           24576/17           2778           1085 NELSON AVE
#
#   EVICTION_APT_NUM EXECUTED_DATE MARSHAL_FIRST_NAME MARSHAL_LAST_NAME  \
# 0              215    09/20/2018             Edward             Guida
# 1           GROUND    09/19/2017             Thomas               Bia
# 2               9H    02/26/2020            Darlene            Barone
# 3               3D    02/26/2020             Ileana            Rivera
# 4               1A    12/13/2017              Vadim       Barbarovich
#
#   RESIDENTIAL_COMMERCIAL_IND    BOROUGH  EVICTION_ZIP
# 0                Residential     QUEENS         11373
# 1                 Commercial  MANHATTAN         10016
# 2                Residential      BRONX         10462
# 3                Residential   BROOKLYN         11225
# 4                Residential      BRONX         10452

# %%
df1['BOROUGH'].value_counts()
# Out:
# BRONX            22034
# BROOKLYN         18800
# QUEENS           13162
# MANHATTAN        10159
# STATEN ISLAND     2168
# Name: BOROUGH, dtype: int64

# %%
df_zipcode=df1[['EVICTION_ZIP']]
df_zipcode.head()
# Out:
#    EVICTION_ZIP
# 0         11373
# 1         10016
# 2         10462
# 3         11225
# 4         10452

# %%
df_zipcode=pd.DataFrame(df_zipcode['EVICTION_ZIP'].value_counts())

# %%
df_zipcode.reset_index(inplace=True)
df_zipcode.rename(columns={'index':'Zip_Code','EVICTION_ZIP':'Counts'},inplace=True)
df_zipcode
# Out:
#      Zip_Code  Counts
# 0       10467    1835
# 1       10458    1799
# 2       10456    1742
# 3       10453    1667
# 4       10457    1462
# ..        ...     ...
# 218     11753       1
# 219     10152       1
# 220     11240       1
# 221     11024       1
# 222     10107       1
#
# [223 rows x 2 columns]

# %%
df_zipcode.columns.values
# Out:
# array(['Zip_Code', 'Counts'], dtype=object)

# %%
df_zipcode
# Out:
#      Zip_Code  Counts
# 0       10467    1835
# 1       10458    1799
# 2       10456    1742
# 3       10453    1667
# 4       10457    1462
# ..        ...     ...
# 218     11753       1
# 219     10152       1
# 220     11240       1
# 221     11024       1
# 222     10107       1
#
# [223 rows x 2 columns]

# %%
df_zipcode=df_zipcode[df_zipcode['Zip_Code']>9999]
df_zipcode['Latitude']=''
df_zipcode['Longitude']=''
df_zipcode.head()
# Out:
# /home/user-1131/venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/user-1131/venv/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Zip_Code  Counts Latitude Longitude
# 0     10467    1835
# 1     10458    1799
# 2     10456    1742
# 3     10453    1667
# 4     10457    1462

# %%
df_zipcode.shape
# Out:
# (221, 4)

# %% [markdown]
# Let's create a dataframe with zip code is NY state

# %%
us_zipcodes=pd.read_csv('us-zip-code-latitude-and-longitude.csv',sep=';')

# %%
us_zipcodes.head()
# Out:
#      Zip      City State   Latitude  Longitude  Timezone  \
# 0  71937      Cove    AR  34.398483  -94.39398        -6
# 1  72044  Edgemont    AR  35.624351  -92.16056        -6
# 2  56171  Sherburn    MN  43.660847  -94.74357        -6
# 3  49430    Lamont    MI  43.010337  -85.89754        -5
# 4  52585  Richland    IA  41.194129  -91.98027        -6
#
#    Daylight savings time flag             geopoint
# 0                           1  34.398483,-94.39398
# 1                           1  35.624351,-92.16056
# 2                           1  43.660847,-94.74357
# 3                           1  43.010337,-85.89754
# 4                           1  41.194129,-91.98027

# %%
ny_state_zip=us_zipcodes[us_zipcodes['State']=='NY']

# %%
ny_state_zip.head()
# Out:
#        Zip           City State   Latitude  Longitude  Timezone  \
# 21   14043          Depew    NY  42.904958 -78.700600        -5
# 72   13827          Owego    NY  42.120274 -76.258740        -5
# 73   14739     Friendship    NY  42.192384 -78.143080        -5
# 85   11703  North Babylon    NY  40.733398 -73.322570        -5
# 131  11707   West Babylon    NY  40.922326 -72.637078        -5
#
#      Daylight savings time flag              geopoint
# 21                            1    42.904958,-78.7006
# 72                            1   42.120274,-76.25874
# 73                            1   42.192384,-78.14308
# 85                            1   40.733398,-73.32257
# 131                           1  40.922326,-72.637078

# %%
ny_state_zip.columns.values
# Out:
# array(['Zip', 'City', 'State', 'Latitude', 'Longitude', 'Timezone',
#        'Daylight savings time flag', 'geopoint'], dtype=object)

# %%
ny_state_zip.rename(columns={'Zip':'Zip_Code'},inplace=True)
ny_state_zip
# Out:
# /home/user-1131/venv/lib/python3.6/site-packages/pandas/core/frame.py:4238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#        Zip_Code              City State   Latitude  Longitude  Timezone  \
# 21        14043             Depew    NY  42.904958 -78.700600        -5
# 72        13827             Owego    NY  42.120274 -76.258740        -5
# 73        14739        Friendship    NY  42.192384 -78.143080        -5
# 85        11703     North Babylon    NY  40.733398 -73.322570        -5
# 131       11707      West Babylon    NY  40.922326 -72.637078        -5
# ...         ...               ...   ...        ...        ...       ...
# 43033     11507         Albertson    NY  40.769942 -73.650040        -5
# 43139     12979      Rouses Point    NY  44.990606 -73.370170        -5
# 43140     13452  Saint Johnsville    NY  43.021223 -74.645370        -5
# 43154     10211          New York    NY  40.780751 -73.977182        -5
# 43155     10532         Hawthorne    NY  41.103664 -73.795800        -5
#
#        Daylight savings time flag              geopoint
# 21                              1    42.904958,-78.7006
# 72                              1   42.120274,-76.25874
# 73                              1   42.192384,-78.14308
# 85                              1   40.733398,-73.32257
# 131                             1  40.922326,-72.637078
# ...                           ...                   ...
# 43033                           1   40.769942,-73.65004
# 43139                           1   44.990606,-73.37017
# 43140                           1   43.021223,-74.64537
# 43154                           1  40.780751,-73.977182
# 43155                           1    41.103664,-73.7958
#
# [2281 rows x 8 columns]

# %% [markdown]
# The next step is to put together df_zipcode with ny_state_zip based on zip code.

# %%
df_combined=pd.merge(df_zipcode,ny_state_zip,on='Zip_Code',how='left')

# %%
df_combined.drop('Latitude_x',axis=1,inplace=True)

# %%
df_combined.drop('Longitude_x',axis=1,inplace=True)

# %%
df_combined.dropna(inplace=True)
df_combined
# Out:
#      Zip_Code  Counts        City State  Latitude_y  Longitude_y  Timezone  \
# 0       10467    1835       Bronx    NY   40.872265   -73.869370      -5.0
# 1       10458    1799       Bronx    NY   40.864166   -73.888810      -5.0
# 2       10456    1742       Bronx    NY   40.829676   -73.908560      -5.0
# 3       10453    1667       Bronx    NY   40.853017   -73.912140      -5.0
# 4       10457    1462       Bronx    NY   40.846745   -73.898610      -5.0
# ..        ...     ...         ...   ...         ...          ...       ...
# 216     11753       1     Jericho    NY   40.786544   -73.536750      -5.0
# 217     10152       1    New York    NY   40.758611   -73.972230      -5.0
# 218     11240       1    Brooklyn    NY   40.645099   -73.945032      -5.0
# 219     11024       1  Great Neck    NY   40.812887   -73.740940      -5.0
# 220     10107       1    New York    NY   40.766429   -73.982728      -5.0
#
#      Daylight savings time flag              geopoint
# 0                           1.0   40.872265,-73.86937
# 1                           1.0   40.864166,-73.88881
# 2                           1.0   40.829676,-73.90856
# 3                           1.0   40.853017,-73.91214
# 4                           1.0   40.846745,-73.89861
# ..                          ...                   ...
# 216                         1.0   40.786544,-73.53675
# 217                         1.0   40.758611,-73.97223
# 218                         1.0  40.645099,-73.945032
# 219                         1.0   40.812887,-73.74094
# 220                         1.0  40.766429,-73.982728
#
# [203 rows x 9 columns]

# %%
df_combined.rename(columns={'Latitude_y':'Latitude','Longitude_y':'Longitude'},inplace=True)

# %% [markdown]
# Let's save a copy of df_combined, just in case.

# %%
df_combined.to_csv('combined_table.csv',index=0)

# %%
df_combined=pd.read_csv('combined_table.csv')
df_combined
# Out:
#      Zip_Code  Counts        City State   Latitude  Longitude  Timezone  \
# 0       10467    1835       Bronx    NY  40.872265 -73.869370      -5.0
# 1       10458    1799       Bronx    NY  40.864166 -73.888810      -5.0
# 2       10456    1742       Bronx    NY  40.829676 -73.908560      -5.0
# 3       10453    1667       Bronx    NY  40.853017 -73.912140      -5.0
# 4       10457    1462       Bronx    NY  40.846745 -73.898610      -5.0
# ..        ...     ...         ...   ...        ...        ...       ...
# 198     11753       1     Jericho    NY  40.786544 -73.536750      -5.0
# 199     10152       1    New York    NY  40.758611 -73.972230      -5.0
# 200     11240       1    Brooklyn    NY  40.645099 -73.945032      -5.0
# 201     11024       1  Great Neck    NY  40.812887 -73.740940      -5.0
# 202     10107       1    New York    NY  40.766429 -73.982728      -5.0
#
#      Daylight savings time flag              geopoint
# 0                           1.0   40.872265,-73.86937
# 1                           1.0   40.864166,-73.88881
# 2                           1.0   40.829676,-73.90856
# 3                           1.0   40.853017,-73.91214
# 4                           1.0   40.846745,-73.89861
# ..                          ...                   ...
# 198                         1.0   40.786544,-73.53675
# 199                         1.0   40.758611,-73.97223
# 200                         1.0  40.645099,-73.945032
# 201                         1.0   40.812887,-73.74094
# 202                         1.0  40.766429,-73.982728
#
# [203 rows x 9 columns]

# %%
df_combined.dtypes
# Out:
# Zip_Code                        int64
# Counts                          int64
# City                           object
# State                          object
# Latitude                      float64
# Longitude                     float64
# Timezone                      float64
# Daylight savings time flag    float64
# geopoint                       object
# dtype: object

# %%
df_combined.shape
# Out:
# (203, 9)

# %%
city='New York City, New York, United States of America'
geolocator=Nominatim(user_agent="nyc_explorer")
location=geolocator.geocode(city)
lat=location.latitude
lon=location.longitude
lat,lon
# Out:
# (40.7127281, -74.0060152)

# %%
NYC_map=folium.Map(location=[lat-0.1,lon],zoom_start=10)        #0.1 is the offset to center the map.
NYC_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We'll mark the latitude and longitude of each zip code and include eviction counts in the label.

# %%
for lat, lon, zipcode,city,counts in zip(df_combined['Latitude'], df_combined['Longitude'], df_combined['Zip_Code'],df_combined['City'],df_combined['Counts']):
    label = 'City: {}, Zipcode: {}, Counts: {}'.format(city,zipcode,counts)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat, lon],
    radius=4,
    popup=label,
    color='orange',
    line_width=1,
    fill=True,
    fill_color='red',
    fill_opacity=0.5,
    parse_html=False).add_to(NYC_map)  
    
NYC_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We cluster the markers to make the map more legible. Hovering mouse over the clusters show the number of markers in it. When we zoom in to individual markers. Hovering over individual markers show the number of evictions.

# %%
#Group markers into different clusters

from folium import plugins #import plugins

latitude=location.latitude
longitude=location.longitude

# let's start again with a clean copy of the map of San Francisco
NYC_map = folium.Map(location = [latitude, longitude], zoom_start = 9)

# instantiate a mark cluster object for the incidents in the dataframe
evictions = plugins.MarkerCluster().add_to(NYC_map)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(df_combined.Latitude, df_combined.Longitude, df_combined.Counts):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(evictions)

# display map
NYC_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# In our next step we'll delve deeper into the residential evictions. Let's take a look at our original dataframe df1. For illustration purpose, this time we'll go over the process again, except we'll use Nominatim to extract coordinates.

# %%
df1.head()
# Out:
#   COURT_INDEX_NUMBER  DOCKET_NUMBER          EVICTION_ADDRESS  \
# 0           62712/18          19077         80-15 41ST AVENUE
# 1           54221/17         332335       31 EAST 31ST STREET
# 2          B42362/19         117551  1605 METROPOLITAN AVENUE
# 3          K85736/19         102339         1236 UNION STREET
# 4           24576/17           2778           1085 NELSON AVE
#
#   EVICTION_APT_NUM EXECUTED_DATE MARSHAL_FIRST_NAME MARSHAL_LAST_NAME  \
# 0              215    09/20/2018             Edward             Guida
# 1           GROUND    09/19/2017             Thomas               Bia
# 2               9H    02/26/2020            Darlene            Barone
# 3               3D    02/26/2020             Ileana            Rivera
# 4               1A    12/13/2017              Vadim       Barbarovich
#
#   RESIDENTIAL_COMMERCIAL_IND    BOROUGH  EVICTION_ZIP
# 0                Residential     QUEENS         11373
# 1                 Commercial  MANHATTAN         10016
# 2                Residential      BRONX         10462
# 3                Residential   BROOKLYN         11225
# 4                Residential      BRONX         10452

# %%
df_evictions_residential=df1[df1['RESIDENTIAL_COMMERCIAL_IND']=='Residential']
df_evictions_residential
# Out:
#       COURT_INDEX_NUMBER  DOCKET_NUMBER                   EVICTION_ADDRESS  \
# 0               62712/18          19077                  80-15 41ST AVENUE
# 2              B42362/19         117551           1605 METROPOLITAN AVENUE
# 3              K85736/19         102339                  1236 UNION STREET
# 4               24576/17           2778                    1085 NELSON AVE
# 6              B55306/17         101402           1129 ST. LAWRENCE AVENUE
# ...                  ...            ...                                ...
# 66317           63498/17          78997                2333 WEBSTER AVENUE
# 66318          N77591/16          76847               408 EAST 64TH STREET
# 66320           68649/17          73953                  712 REMSEN AVENUE
# 66321           77370/18          22034         110-19 FRANCIS LEWIS BLVD.
# 66322           75246/16           4238  360 MONTAUK AVE. APT. 2 2ND FLOOR
#
#       EVICTION_APT_NUM EXECUTED_DATE MARSHAL_FIRST_NAME MARSHAL_LAST_NAME  \
# 0                  215    09/20/2018             Edward             Guida
# 2                   9H    02/26/2020            Darlene            Barone
# 3                   3D    02/26/2020             Ileana            Rivera
# 4                   1A    12/13/2017              Vadim       Barbarovich
# 6                   4D    12/19/2018            Darlene            Barone
# ...                ...           ...                ...               ...
# 66317               3L    02/15/2018              Henry             Daley
# 66318               2B    05/17/2017             Ileana            Rivera
# 66320              NaN    09/15/2017              Henry             Daley
# 66321              NaN    05/28/2019             Edward             Guida
# 66322                2    01/09/2017             Robert          Renzulli
#
#       RESIDENTIAL_COMMERCIAL_IND    BOROUGH  EVICTION_ZIP
# 0                    Residential     QUEENS         11373
# 2                    Residential      BRONX         10462
# 3                    Residential   BROOKLYN         11225
# 4                    Residential      BRONX         10452
# 6                    Residential      BRONX         10472
# ...                          ...        ...           ...
# 66317                Residential      BRONX         10458
# 66318                Residential  MANHATTAN         10065
# 66320                Residential   BROOKLYN         11236
# 66321                Residential     QUEENS         11429
# 66322                Residential   BROOKLYN         11208
#
# [60747 rows x 10 columns]

# %%
df_evictions_residential.columns.values
# Out:
# array(['COURT_INDEX_NUMBER', 'DOCKET_NUMBER', 'EVICTION_ADDRESS',
#        'EVICTION_APT_NUM', 'EXECUTED_DATE', 'MARSHAL_FIRST_NAME',
#        'MARSHAL_LAST_NAME', 'RESIDENTIAL_COMMERCIAL_IND', 'BOROUGH',
#        'EVICTION_ZIP'], dtype=object)

# %% [markdown]
# We'll drop all the columns except 'EVICTION_ADDRESS', 'EXECUTED_DATE', 'RESIDENTIAL_COMMERCIAL_IND', 'BOROUGH' and 'EVICTION_ZIP'.

# %%
df_evictions_residential.drop('COURT_INDEX_NUMBER',axis=1,inplace=True)
df_evictions_residential.drop('DOCKET_NUMBER',axis=1,inplace=True)
df_evictions_residential.drop('EVICTION_APT_NUM',axis=1,inplace=True)
df_evictions_residential.drop('MARSHAL_FIRST_NAME',axis=1,inplace=True)
df_evictions_residential.drop('MARSHAL_LAST_NAME',axis=1,inplace=True)

df_evictions_residential.head()
# Out:
# /home/user-1131/venv/lib/python3.6/site-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#            EVICTION_ADDRESS EXECUTED_DATE RESIDENTIAL_COMMERCIAL_IND  \
# 0         80-15 41ST AVENUE    09/20/2018                Residential
# 2  1605 METROPOLITAN AVENUE    02/26/2020                Residential
# 3         1236 UNION STREET    02/26/2020                Residential
# 4           1085 NELSON AVE    12/13/2017                Residential
# 6  1129 ST. LAWRENCE AVENUE    12/19/2018                Residential
#
#     BOROUGH  EVICTION_ZIP
# 0    QUEENS         11373
# 2     BRONX         10462
# 3  BROOKLYN         11225
# 4     BRONX         10452
# 6     BRONX         10472

# %% [markdown]
# Next we remove all rows with NaNs.

# %%
df_evictions_residential.dropna(inplace=True)
# Out:
# /home/user-1131/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Let's take a look at the number of rows and columns.

# %%
df_evictions_residential.shape
# Out:
# (60747, 5)

# %%
df_evictions_residential
# Out:
#                         EVICTION_ADDRESS EXECUTED_DATE  \
# 0                      80-15 41ST AVENUE    09/20/2018
# 2               1605 METROPOLITAN AVENUE    02/26/2020
# 3                      1236 UNION STREET    02/26/2020
# 4                        1085 NELSON AVE    12/13/2017
# 6               1129 ST. LAWRENCE AVENUE    12/19/2018
# ...                                  ...           ...
# 66317                2333 WEBSTER AVENUE    02/15/2018
# 66318               408 EAST 64TH STREET    05/17/2017
# 66320                  712 REMSEN AVENUE    09/15/2017
# 66321         110-19 FRANCIS LEWIS BLVD.    05/28/2019
# 66322  360 MONTAUK AVE. APT. 2 2ND FLOOR    01/09/2017
#
#       RESIDENTIAL_COMMERCIAL_IND    BOROUGH  EVICTION_ZIP
# 0                    Residential     QUEENS         11373
# 2                    Residential      BRONX         10462
# 3                    Residential   BROOKLYN         11225
# 4                    Residential      BRONX         10452
# 6                    Residential      BRONX         10472
# ...                          ...        ...           ...
# 66317                Residential      BRONX         10458
# 66318                Residential  MANHATTAN         10065
# 66320                Residential   BROOKLYN         11236
# 66321                Residential     QUEENS         11429
# 66322                Residential   BROOKLYN         11208
#
# [60747 rows x 5 columns]

# %%
df3=df_evictions_residential

# %% [markdown]
# To look up using Nominatim package, we need a complete address. To have that handy we add a new column named 'LOOKUP ADDRESS'.

# %%
df3
# Out:
#                         EVICTION_ADDRESS EXECUTED_DATE  \
# 0                      80-15 41ST AVENUE    09/20/2018
# 2               1605 METROPOLITAN AVENUE    02/26/2020
# 3                      1236 UNION STREET    02/26/2020
# 4                        1085 NELSON AVE    12/13/2017
# 6               1129 ST. LAWRENCE AVENUE    12/19/2018
# ...                                  ...           ...
# 66317                2333 WEBSTER AVENUE    02/15/2018
# 66318               408 EAST 64TH STREET    05/17/2017
# 66320                  712 REMSEN AVENUE    09/15/2017
# 66321         110-19 FRANCIS LEWIS BLVD.    05/28/2019
# 66322  360 MONTAUK AVE. APT. 2 2ND FLOOR    01/09/2017
#
#       RESIDENTIAL_COMMERCIAL_IND    BOROUGH  EVICTION_ZIP
# 0                    Residential     QUEENS         11373
# 2                    Residential      BRONX         10462
# 3                    Residential   BROOKLYN         11225
# 4                    Residential      BRONX         10452
# 6                    Residential      BRONX         10472
# ...                          ...        ...           ...
# 66317                Residential      BRONX         10458
# 66318                Residential  MANHATTAN         10065
# 66320                Residential   BROOKLYN         11236
# 66321                Residential     QUEENS         11429
# 66322                Residential   BROOKLYN         11208
#
# [60747 rows x 5 columns]

# %%
df3['FULL_ADDRESS']=''
df3
# Out:
# /home/user-1131/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                         EVICTION_ADDRESS EXECUTED_DATE  \
# 0                      80-15 41ST AVENUE    09/20/2018
# 2               1605 METROPOLITAN AVENUE    02/26/2020
# 3                      1236 UNION STREET    02/26/2020
# 4                        1085 NELSON AVE    12/13/2017
# 6               1129 ST. LAWRENCE AVENUE    12/19/2018
# ...                                  ...           ...
# 66317                2333 WEBSTER AVENUE    02/15/2018
# 66318               408 EAST 64TH STREET    05/17/2017
# 66320                  712 REMSEN AVENUE    09/15/2017
# 66321         110-19 FRANCIS LEWIS BLVD.    05/28/2019
# 66322  360 MONTAUK AVE. APT. 2 2ND FLOOR    01/09/2017
#
#       RESIDENTIAL_COMMERCIAL_IND    BOROUGH  EVICTION_ZIP FULL_ADDRESS
# 0                    Residential     QUEENS         11373
# 2                    Residential      BRONX         10462
# 3                    Residential   BROOKLYN         11225
# 4                    Residential      BRONX         10452
# 6                    Residential      BRONX         10472
# ...                          ...        ...           ...          ...
# 66317                Residential      BRONX         10458
# 66318                Residential  MANHATTAN         10065
# 66320                Residential   BROOKLYN         11236
# 66321                Residential     QUEENS         11429
# 66322                Residential   BROOKLYN         11208
#
# [60747 rows x 6 columns]

# %%
pd.DataFrame.to_string(df3[['EVICTION_ZIP']])
type(df3[['EVICTION_ZIP']])
# Out:
# pandas.core.frame.DataFrame

# %%
df3.dtypes
# Out:
# EVICTION_ADDRESS              object
# EXECUTED_DATE                 object
# RESIDENTIAL_COMMERCIAL_IND    object
# BOROUGH                       object
# EVICTION_ZIP                   int64
# FULL_ADDRESS                  object
# dtype: object

# %%
df3=df3.replace('\*','',regex=True).astype(str)
df3['EVICTION_ADDRESS']
# Out:
# 0                        80-15 41ST AVENUE
# 2                 1605 METROPOLITAN AVENUE
# 3                        1236 UNION STREET
# 4                          1085 NELSON AVE
# 6                 1129 ST. LAWRENCE AVENUE
#                        ...
# 66317                  2333 WEBSTER AVENUE
# 66318                 408 EAST 64TH STREET
# 66320                    712 REMSEN AVENUE
# 66321           110-19 FRANCIS LEWIS BLVD.
# 66322    360 MONTAUK AVE. APT. 2 2ND FLOOR
# Name: EVICTION_ADDRESS, Length: 60747, dtype: object

# %%
df3['FULL_ADDRESS']=df3['EVICTION_ADDRESS']+', NY '+df3['EVICTION_ZIP']
df3['FULL_ADDRESS']
# Out:
# 0                        80-15 41ST AVENUE, NY 11373
# 2                 1605 METROPOLITAN AVENUE, NY 10462
# 3                        1236 UNION STREET, NY 11225
# 4                          1085 NELSON AVE, NY 10452
# 6                 1129 ST. LAWRENCE AVENUE, NY 10472
#                             ...
# 66317                  2333 WEBSTER AVENUE, NY 10458
# 66318                 408 EAST 64TH STREET, NY 10065
# 66320                    712 REMSEN AVENUE, NY 11236
# 66321           110-19 FRANCIS LEWIS BLVD., NY 11429
# 66322    360 MONTAUK AVE. APT. 2 2ND FLOOR, NY 11208
# Name: FULL_ADDRESS, Length: 60747, dtype: object

# %%
df3.reset_index(inplace=True)
df3.drop('index',axis=1,inplace=True)

# %%
df3.head()
# Out:
#            EVICTION_ADDRESS EXECUTED_DATE RESIDENTIAL_COMMERCIAL_IND  \
# 0         80-15 41ST AVENUE    09/20/2018                Residential
# 1  1605 METROPOLITAN AVENUE    02/26/2020                Residential
# 2         1236 UNION STREET    02/26/2020                Residential
# 3           1085 NELSON AVE    12/13/2017                Residential
# 4  1129 ST. LAWRENCE AVENUE    12/19/2018                Residential
#
#     BOROUGH EVICTION_ZIP                        FULL_ADDRESS
# 0    QUEENS        11373         80-15 41ST AVENUE, NY 11373
# 1     BRONX        10462  1605 METROPOLITAN AVENUE, NY 10462
# 2  BROOKLYN        11225         1236 UNION STREET, NY 11225
# 3     BRONX        10452           1085 NELSON AVE, NY 10452
# 4     BRONX        10472  1129 ST. LAWRENCE AVENUE, NY 10472

# %% [markdown]
# The list is too long to use Nominatim. Let's create new columns for city and its latitude and longitude.

# %%
df3['City']=''
df3['City_Latitude']=''
df3['City_Longitude']=''

# %%
df3.rename(columns={'EVICTION_ZIP':'Zip_Code'},inplace=True)
df3.head()
# Out:
#            EVICTION_ADDRESS EXECUTED_DATE RESIDENTIAL_COMMERCIAL_IND  \
# 0         80-15 41ST AVENUE    09/20/2018                Residential
# 1  1605 METROPOLITAN AVENUE    02/26/2020                Residential
# 2         1236 UNION STREET    02/26/2020                Residential
# 3           1085 NELSON AVE    12/13/2017                Residential
# 4  1129 ST. LAWRENCE AVENUE    12/19/2018                Residential
#
#     BOROUGH Zip_Code                        FULL_ADDRESS City City_Latitude  \
# 0    QUEENS    11373         80-15 41ST AVENUE, NY 11373
# 1     BRONX    10462  1605 METROPOLITAN AVENUE, NY 10462
# 2  BROOKLYN    11225         1236 UNION STREET, NY 11225
# 3     BRONX    10452           1085 NELSON AVE, NY 10452
# 4     BRONX    10472  1129 ST. LAWRENCE AVENUE, NY 10472
#
#   City_Longitude
# 0
# 1
# 2
# 3
# 4

# %%
df3.dtypes
# Out:
# EVICTION_ADDRESS              object
# EXECUTED_DATE                 object
# RESIDENTIAL_COMMERCIAL_IND    object
# BOROUGH                       object
# Zip_Code                      object
# FULL_ADDRESS                  object
# City                          object
# City_Latitude                 object
# City_Longitude                object
# dtype: object

# %%
df_combined.dtypes
# Out:
# Zip_Code                        int64
# Counts                          int64
# City                           object
# State                          object
# Latitude                      float64
# Longitude                     float64
# Timezone                      float64
# Daylight savings time flag    float64
# geopoint                       object
# dtype: object

# %%
df3['Zip_Code']=pd.to_numeric(df3['Zip_Code'])
df3.dtypes
# Out:
# EVICTION_ADDRESS              object
# EXECUTED_DATE                 object
# RESIDENTIAL_COMMERCIAL_IND    object
# BOROUGH                       object
# Zip_Code                       int64
# FULL_ADDRESS                  object
# City                          object
# City_Latitude                 object
# City_Longitude                object
# dtype: object

# %%
df3=pd.merge(df3,df_combined,on='Zip_Code',how='left')

# %%
df3
# Out:
#                         EVICTION_ADDRESS EXECUTED_DATE  \
# 0                      80-15 41ST AVENUE    09/20/2018
# 1               1605 METROPOLITAN AVENUE    02/26/2020
# 2                      1236 UNION STREET    02/26/2020
# 3                        1085 NELSON AVE    12/13/2017
# 4               1129 ST. LAWRENCE AVENUE    12/19/2018
# ...                                  ...           ...
# 60742                2333 WEBSTER AVENUE    02/15/2018
# 60743               408 EAST 64TH STREET    05/17/2017
# 60744                  712 REMSEN AVENUE    09/15/2017
# 60745         110-19 FRANCIS LEWIS BLVD.    05/28/2019
# 60746  360 MONTAUK AVE. APT. 2 2ND FLOOR    01/09/2017
#
#       RESIDENTIAL_COMMERCIAL_IND    BOROUGH  Zip_Code  \
# 0                    Residential     QUEENS     11373
# 1                    Residential      BRONX     10462
# 2                    Residential   BROOKLYN     11225
# 3                    Residential      BRONX     10452
# 4                    Residential      BRONX     10472
# ...                          ...        ...       ...
# 60742                Residential      BRONX     10458
# 60743                Residential  MANHATTAN     10065
# 60744                Residential   BROOKLYN     11236
# 60745                Residential     QUEENS     11429
# 60746                Residential   BROOKLYN     11208
#
#                                       FULL_ADDRESS City_x City_Latitude  \
# 0                      80-15 41ST AVENUE, NY 11373
# 1               1605 METROPOLITAN AVENUE, NY 10462
# 2                      1236 UNION STREET, NY 11225
# 3                        1085 NELSON AVE, NY 10452
# 4               1129 ST. LAWRENCE AVENUE, NY 10472
# ...                                            ...    ...           ...
# 60742                2333 WEBSTER AVENUE, NY 10458
# 60743               408 EAST 64TH STREET, NY 10065
# 60744                  712 REMSEN AVENUE, NY 11236
# 60745         110-19 FRANCIS LEWIS BLVD., NY 11429
# 60746  360 MONTAUK AVE. APT. 2 2ND FLOOR, NY 11208
#
#       City_Longitude  Counts          City_y State   Latitude  Longitude  \
# 0                      391.0        Elmhurst    NY  40.736076  -73.87804
# 1                     1020.0           Bronx    NY  40.842173  -73.85862
# 2                      649.0        Brooklyn    NY  40.662892  -73.95509
# 3                     1259.0           Bronx    NY  40.838745  -73.92234
# 4                     1000.0           Bronx    NY  40.830409  -73.86845
# ...              ...     ...             ...   ...        ...        ...
# 60742                 1799.0           Bronx    NY  40.864166  -73.88881
# 60743                    NaN             NaN   NaN        NaN        NaN
# 60744                  851.0        Brooklyn    NY  40.640527  -73.90362
# 60745                  219.0  Queens Village    NY  40.708833  -73.73903
# 60746                 1347.0        Brooklyn    NY  40.672666  -73.87248
#
#        Timezone  Daylight savings time flag             geopoint
# 0          -5.0                         1.0  40.736076,-73.87804
# 1          -5.0                         1.0  40.842173,-73.85862
# 2          -5.0                         1.0  40.662892,-73.95509
# 3          -5.0                         1.0  40.838745,-73.92234
# 4          -5.0                         1.0  40.830409,-73.86845
# ...         ...                         ...                  ...
# 60742      -5.0                         1.0  40.864166,-73.88881
# 60743       NaN                         NaN                  NaN
# 60744      -5.0                         1.0  40.640527,-73.90362
# 60745      -5.0                         1.0  40.708833,-73.73903
# 60746      -5.0                         1.0  40.672666,-73.87248
#
# [60747 rows x 17 columns]

# %% [markdown]
# Let's cross-check tables were merged correctly.

# %%
df_combined[df_combined['Zip_Code']==11373]
# Out:
#     Zip_Code  Counts      City State   Latitude  Longitude  Timezone  \
# 51     11373     391  Elmhurst    NY  40.736076  -73.87804      -5.0
#
#     Daylight savings time flag             geopoint
# 51                         1.0  40.736076,-73.87804

# %% [markdown]
# We have some NAN values. Let's drop all na's.

# %%
df3.dropna(inplace=True)
df3
# Out:
#                         EVICTION_ADDRESS EXECUTED_DATE  \
# 0                      80-15 41ST AVENUE    09/20/2018
# 1               1605 METROPOLITAN AVENUE    02/26/2020
# 2                      1236 UNION STREET    02/26/2020
# 3                        1085 NELSON AVE    12/13/2017
# 4               1129 ST. LAWRENCE AVENUE    12/19/2018
# ...                                  ...           ...
# 60741                  2171 BRAGG STREET    09/18/2018
# 60742                2333 WEBSTER AVENUE    02/15/2018
# 60744                  712 REMSEN AVENUE    09/15/2017
# 60745         110-19 FRANCIS LEWIS BLVD.    05/28/2019
# 60746  360 MONTAUK AVE. APT. 2 2ND FLOOR    01/09/2017
#
#       RESIDENTIAL_COMMERCIAL_IND   BOROUGH  Zip_Code  \
# 0                    Residential    QUEENS     11373
# 1                    Residential     BRONX     10462
# 2                    Residential  BROOKLYN     11225
# 3                    Residential     BRONX     10452
# 4                    Residential     BRONX     10472
# ...                          ...       ...       ...
# 60741                Residential  BROOKLYN     11229
# 60742                Residential     BRONX     10458
# 60744                Residential  BROOKLYN     11236
# 60745                Residential    QUEENS     11429
# 60746                Residential  BROOKLYN     11208
#
#                                       FULL_ADDRESS City_x City_Latitude  \
# 0                      80-15 41ST AVENUE, NY 11373
# 1               1605 METROPOLITAN AVENUE, NY 10462
# 2                      1236 UNION STREET, NY 11225
# 3                        1085 NELSON AVE, NY 10452
# 4               1129 ST. LAWRENCE AVENUE, NY 10472
# ...                                            ...    ...           ...
# 60741                  2171 BRAGG STREET, NY 11229
# 60742                2333 WEBSTER AVENUE, NY 10458
# 60744                  712 REMSEN AVENUE, NY 11236
# 60745         110-19 FRANCIS LEWIS BLVD., NY 11429
# 60746  360 MONTAUK AVE. APT. 2 2ND FLOOR, NY 11208
#
#       City_Longitude  Counts          City_y State   Latitude  Longitude  \
# 0                      391.0        Elmhurst    NY  40.736076  -73.87804
# 1                     1020.0           Bronx    NY  40.842173  -73.85862
# 2                      649.0        Brooklyn    NY  40.662892  -73.95509
# 3                     1259.0           Bronx    NY  40.838745  -73.92234
# 4                     1000.0           Bronx    NY  40.830409  -73.86845
# ...              ...     ...             ...   ...        ...        ...
# 60741                  320.0        Brooklyn    NY  40.599256  -73.94118
# 60742                 1799.0           Bronx    NY  40.864166  -73.88881
# 60744                  851.0        Brooklyn    NY  40.640527  -73.90362
# 60745                  219.0  Queens Village    NY  40.708833  -73.73903
# 60746                 1347.0        Brooklyn    NY  40.672666  -73.87248
#
#        Timezone  Daylight savings time flag             geopoint
# 0          -5.0                         1.0  40.736076,-73.87804
# 1          -5.0                         1.0  40.842173,-73.85862
# 2          -5.0                         1.0  40.662892,-73.95509
# 3          -5.0                         1.0  40.838745,-73.92234
# 4          -5.0                         1.0  40.830409,-73.86845
# ...         ...                         ...                  ...
# 60741      -5.0                         1.0  40.599256,-73.94118
# 60742      -5.0                         1.0  40.864166,-73.88881
# 60744      -5.0                         1.0  40.640527,-73.90362
# 60745      -5.0                         1.0  40.708833,-73.73903
# 60746      -5.0                         1.0  40.672666,-73.87248
#
# [60555 rows x 17 columns]

# %%
df3.drop(['City_x','City_Latitude','City_Longitude','Counts'], axis=1,inplace=True)

# %%
df3.rename(columns={'City_y':'City'},inplace=True)

# %%
df3.head()
# Out:
#            EVICTION_ADDRESS EXECUTED_DATE RESIDENTIAL_COMMERCIAL_IND  \
# 0         80-15 41ST AVENUE    09/20/2018                Residential
# 1  1605 METROPOLITAN AVENUE    02/26/2020                Residential
# 2         1236 UNION STREET    02/26/2020                Residential
# 3           1085 NELSON AVE    12/13/2017                Residential
# 4  1129 ST. LAWRENCE AVENUE    12/19/2018                Residential
#
#     BOROUGH  Zip_Code                        FULL_ADDRESS      City State  \
# 0    QUEENS     11373         80-15 41ST AVENUE, NY 11373  Elmhurst    NY
# 1     BRONX     10462  1605 METROPOLITAN AVENUE, NY 10462     Bronx    NY
# 2  BROOKLYN     11225         1236 UNION STREET, NY 11225  Brooklyn    NY
# 3     BRONX     10452           1085 NELSON AVE, NY 10452     Bronx    NY
# 4     BRONX     10472  1129 ST. LAWRENCE AVENUE, NY 10472     Bronx    NY
#
#     Latitude  Longitude  Timezone  Daylight savings time flag  \
# 0  40.736076  -73.87804      -5.0                         1.0
# 1  40.842173  -73.85862      -5.0                         1.0
# 2  40.662892  -73.95509      -5.0                         1.0
# 3  40.838745  -73.92234      -5.0                         1.0
# 4  40.830409  -73.86845      -5.0                         1.0
#
#               geopoint
# 0  40.736076,-73.87804
# 1  40.842173,-73.85862
# 2  40.662892,-73.95509
# 3  40.838745,-73.92234
# 4  40.830409,-73.86845

# %% [markdown]
# The table is in a very user-friendly format at the moment. Let's save a copy in a csv file, just in case.

# %%
df3.to_csv('nyc_evictions_details.csv',index=0)

# %%
df4=df3.copy(deep=True)
df4.head()
# Out:
#            EVICTION_ADDRESS EXECUTED_DATE RESIDENTIAL_COMMERCIAL_IND  \
# 0         80-15 41ST AVENUE    09/20/2018                Residential
# 1  1605 METROPOLITAN AVENUE    02/26/2020                Residential
# 2         1236 UNION STREET    02/26/2020                Residential
# 3           1085 NELSON AVE    12/13/2017                Residential
# 4  1129 ST. LAWRENCE AVENUE    12/19/2018                Residential
#
#     BOROUGH  Zip_Code                        FULL_ADDRESS      City State  \
# 0    QUEENS     11373         80-15 41ST AVENUE, NY 11373  Elmhurst    NY
# 1     BRONX     10462  1605 METROPOLITAN AVENUE, NY 10462     Bronx    NY
# 2  BROOKLYN     11225         1236 UNION STREET, NY 11225  Brooklyn    NY
# 3     BRONX     10452           1085 NELSON AVE, NY 10452     Bronx    NY
# 4     BRONX     10472  1129 ST. LAWRENCE AVENUE, NY 10472     Bronx    NY
#
#     Latitude  Longitude  Timezone  Daylight savings time flag  \
# 0  40.736076  -73.87804      -5.0                         1.0
# 1  40.842173  -73.85862      -5.0                         1.0
# 2  40.662892  -73.95509      -5.0                         1.0
# 3  40.838745  -73.92234      -5.0                         1.0
# 4  40.830409  -73.86845      -5.0                         1.0
#
#               geopoint
# 0  40.736076,-73.87804
# 1  40.842173,-73.85862
# 2  40.662892,-73.95509
# 3  40.838745,-73.92234
# 4  40.830409,-73.86845

# %%
df4=df4[['City','State','Latitude','Longitude']]

# %%
df_city_counts=pd.DataFrame(df4['City'].value_counts())

# %%
df_city_counts.head()
# Out:
#                 City
# Bronx          21190
# Brooklyn       17364
# New York        7987
# Jamaica         2108
# Staten Island   2046

# %% [markdown]
# We'll change some things to make the table more usable. Then we'll add in the coordinates.

# %%
df_city_counts.reset_index(inplace=True)
df_city_counts.rename(columns={'City':'Count_of_Evictions'},inplace=True)
df_city_counts.rename(columns={'index':'City'},inplace=True)
df_city_counts['Latitude']=''
df_city_counts['Longitude']=''

# %%
df_city_counts.head()
# Out:
#             City  Count_of_Evictions Latitude Longitude
# 0          Bronx               21190
# 1       Brooklyn               17364
# 2       New York                7987
# 3        Jamaica                2108
# 4  Staten Island                2046

# %%
df_city_counts.iloc[0,0]
# Out:
# 'Bronx'

# %%
df_city_counts['City']=df_city_counts['City']+', NY'

# %%
df_city_counts
# Out:
#                        City  Count_of_Evictions Latitude Longitude
# 0                 Bronx, NY               21190
# 1              Brooklyn, NY               17364
# 2              New York, NY                7987
# 3               Jamaica, NY                2108
# 4         Staten Island, NY                2046
# 5          Far Rockaway, NY                 960
# 6              Flushing, NY                 870
# 7                Corona, NY                 656
# 8               Astoria, NY                 563
# 9             Ridgewood, NY                 427
# 10       Queens Village, NY                 413
# 11              Arverne, NY                 359
# 12           Ozone Park, NY                 355
# 13             Elmhurst, NY                 343
# 14  Springfield Gardens, NY                 327
# 15      Jackson Heights, NY                 319
# 16             Woodside, NY                 305
# 17         Saint Albans, NY                 295
# 18     South Ozone Park, NY                 272
# 19               Hollis, NY                 251
# 20        Fresh Meadows, NY                 235
# 21             Rosedale, NY                 230
# 22        Richmond Hill, NY                 216
# 23  South Richmond Hill, NY                 212
# 24         Forest Hills, NY                 208
# 25            Woodhaven, NY                 200
# 26     Long Island City, NY                 198
# 27        East Elmhurst, NY                 191
# 28            Rego Park, NY                 188
# 29          Kew Gardens, NY                 151
# 30            Sunnyside, NY                 141
# 31        Rockaway Park, NY                 135
# 32        College Point, NY                 122
# 33              Maspeth, NY                 119
# 34              Bayside, NY                 110
# 35      Cambria Heights, NY                  95
# 36         Howard Beach, NY                  92
# 37       Middle Village, NY                  72
# 38      Oakland Gardens, NY                  64
# 39           Whitestone, NY                  61
# 40            Bellerose, NY                  40
# 41          Little Neck, NY                  32
# 42            Glen Oaks, NY                  16
# 43        New Hyde Park, NY                   8
# 44          Floral Park, NY                   5
# 45            Roosevelt, NY                   2
# 46           Great Neck, NY                   1
# 47          Carle Place, NY                   1

# %%
city=df_city_counts.iloc[2,0]

# %%
geolocator=Nominatim(user_agent="nyc_explorer")
location=geolocator.geocode(city)
lat=location.latitude
lon=location.longitude
lat,lon
# Out:
# (40.7127281, -74.0060152)

# %%
i=0
while i<len(df_city_counts.index):
    df_city_counts.iloc[i,2]=geolocator.geocode(df_city_counts.iloc[i,0]).latitude
    df_city_counts.iloc[i,3]=geolocator.geocode(df_city_counts.iloc[i,0]).longitude
    i+=1
df_city_counts.head()
# Out:
#                 City  Count_of_Evictions Latitude Longitude
# 0          Bronx, NY               21190  40.8467  -73.8786
# 1       Brooklyn, NY               17364  40.6501  -73.9496
# 2       New York, NY                7987  40.7127   -74.006
# 3        Jamaica, NY                2108  40.6915  -73.8057
# 4  Staten Island, NY                2046  40.5835  -74.1496

# %% [markdown]
# City in this dataset refers to neighborhood. So let's rename the column accordingly.

# %%
df_city_counts.rename(columns={'City':'Neighborhood'},inplace=True)

# %%
df_city_counts.head()
# Out:
#         Neighborhood  Count_of_Evictions Latitude Longitude
# 0          Bronx, NY               21190  40.8467  -73.8786
# 1       Brooklyn, NY               17364  40.6501  -73.9496
# 2       New York, NY                7987  40.7127   -74.006
# 3        Jamaica, NY                2108  40.6915  -73.8057
# 4  Staten Island, NY                2046  40.5835  -74.1496

# %% [markdown]
# This is a good time to save the df_city_counts dataframe in a csv file.

# %%
df_city_counts.to_csv('nyc_evictions_counts_geo.csv',index=0)

# %%
NY_eviction_map=folium.Map(location=[lat-0.1,lon],zoom_start=10)        #0.1 is the offset to center the map.
NY_eviction_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_city_counts.head(50)
# Out:
#                Neighborhood  Count_of_Evictions Latitude Longitude
# 0                 Bronx, NY               21190  40.8467  -73.8786
# 1              Brooklyn, NY               17364  40.6501  -73.9496
# 2              New York, NY                7987  40.7127   -74.006
# 3               Jamaica, NY                2108  40.6915  -73.8057
# 4         Staten Island, NY                2046  40.5835  -74.1496
# 5          Far Rockaway, NY                 960  40.6054  -73.7551
# 6              Flushing, NY                 870  40.7654  -73.8174
# 7                Corona, NY                 656   40.747  -73.8601
# 8               Astoria, NY                 563   40.772  -73.9303
# 9             Ridgewood, NY                 427  40.7081  -73.9142
# 10       Queens Village, NY                 413  40.7268  -73.7415
# 11              Arverne, NY                 359  40.5934  -73.7895
# 12           Ozone Park, NY                 355  40.6768  -73.8437
# 13             Elmhurst, NY                 343  40.7366  -73.8784
# 14  Springfield Gardens, NY                 327  40.6782  -73.7465
# 15      Jackson Heights, NY                 319  40.7557  -73.8858
# 16             Woodside, NY                 305  40.7454  -73.9054
# 17         Saint Albans, NY                 295  40.6984  -73.7607
# 18     South Ozone Park, NY                 272  40.6701   -73.819
# 19               Hollis, NY                 251  40.7134  -73.7671
# 20        Fresh Meadows, NY                 235  40.7348  -73.7935
# 21             Rosedale, NY                 230   40.662  -73.7354
# 22        Richmond Hill, NY                 216  40.6994   -73.831
# 23  South Richmond Hill, NY                 212  40.6994   -73.831
# 24         Forest Hills, NY                 208  40.7196  -73.8449
# 25            Woodhaven, NY                 200  40.6893  -73.8579
# 26     Long Island City, NY                 198  40.7415   -73.957
# 27        East Elmhurst, NY                 191  40.7612  -73.8651
# 28            Rego Park, NY                 188  40.7229  -73.8622
# 29          Kew Gardens, NY                 151  40.7139  -73.8307
# 30            Sunnyside, NY                 141  40.7398  -73.9354
# 31        Rockaway Park, NY                 135  40.5805  -73.8362
# 32        College Point, NY                 122  40.7876   -73.846
# 33              Maspeth, NY                 119  40.7232  -73.9126
# 34              Bayside, NY                 110  40.7684  -73.7771
# 35      Cambria Heights, NY                  95  40.6945  -73.7385
# 36         Howard Beach, NY                  92  40.6579  -73.8362
# 37       Middle Village, NY                  72  40.7182  -73.8787
# 38      Oakland Gardens, NY                  64   40.754   -73.766
# 39           Whitestone, NY                  61  40.7945  -73.8185
# 40            Bellerose, NY                  40  40.7243  -73.7151
# 41          Little Neck, NY                  32  40.7745  -73.7413
# 42            Glen Oaks, NY                  16   40.747  -73.7115
# 43        New Hyde Park, NY                   8  40.7308  -73.6805
# 44          Floral Park, NY                   5  40.7247  -73.7048
# 45            Roosevelt, NY                   2  40.6781  -73.5855
# 46           Great Neck, NY                   1  40.8007  -73.7285
# 47          Carle Place, NY                   1  40.7493  -73.6038

# %%
df_neighborhood_pop=pd.read_csv('New_York_City_Population_By_Neighborhood_Tabulation_Areas.csv')
df_neighborhood_pop.head()
# Out:
#   Borough  Year  FIPS County Code NTA Code                         NTA Name  \
# 0   Bronx  2000                 5     BX01               Claremont-Bathgate
# 1   Bronx  2000                 5     BX03  Eastchester-Edenwald-Baychester
# 2   Bronx  2000                 5     BX05       Bedford Park-Fordham North
# 3   Bronx  2000                 5     BX06                          Belmont
# 4   Bronx  2000                 5     BX07                        Bronxdale
#
#    Population
# 0       28149
# 1       35422
# 2       55329
# 3       25967
# 4       34309

# %%
df_neighborhood_pop['Year'].unique
# Out:
# <bound method Series.unique of 0      2000
# 1      2000
# 2      2000
# 3      2000
# 4      2000
#        ...
# 385    2010
# 386    2010
# 387    2010
# 388    2010
# 389    2010
# Name: Year, Length: 390, dtype: int64>

# %% [markdown]
# We'll select population data from 2010 as it's the most recent data available.

# %%
df_pop_2010=df_neighborhood_pop[df_neighborhood_pop['Year']==2010]

# %% [markdown]
# We need to rename the column 'NTA Code' to 'Neighborhood' so we can merge df_city_counts and df_pop_2010.

# %%
df_pop_2010.rename(columns={'NTA Name':'Neighborhood'},inplace=True)
df_pop_2010
# Out:
#            Borough  Year  FIPS County Code NTA Code  \
# 195          Bronx  2010                 5     BX01
# 196          Bronx  2010                 5     BX03
# 197          Bronx  2010                 5     BX05
# 198          Bronx  2010                 5     BX06
# 199          Bronx  2010                 5     BX07
# ..             ...   ...               ...      ...
# 385  Staten Island  2010                85     SI37
# 386  Staten Island  2010                85     SI45
# 387  Staten Island  2010                85     SI48
# 388  Staten Island  2010                85     SI54
# 389  Staten Island  2010                85     SI99
#
#                         Neighborhood  Population
# 195               Claremont-Bathgate       31078
# 196  Eastchester-Edenwald-Baychester       34517
# 197       Bedford Park-Fordham North       54415
# 198                          Belmont       27378
# 199                        Bronxdale       35538
# ..                               ...         ...
# 385               Stapleton-Rosebank       26453
# 386           New Dorp-Midland Beach       21896
# 387                    Arden Heights       25238
# 388                      Great Kills       40720
# 389  park-cemetery-etc-Staten Island           0
#
# [195 rows x 6 columns]

# %%
df_city_counts['Population']=''

# %% [markdown]
# Let's save the dataframe in its own csv.

# %%
df_pop_2010.to_csv('nyc_pop_2010.csv',index=0)

# %% [markdown]
# Add the string ', NY' to all values in df_pop_2010['Neighborhood'] to match neighborhood names in df_city_counts.

# %%
df_pop_2010['Neighborhood']=df_pop_2010['Neighborhood']+', NY'
# Out:
# /home/user-1131/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_pop_2010
# Out:
#            Borough  Year  FIPS County Code NTA Code  \
# 195          Bronx  2010                 5     BX01
# 196          Bronx  2010                 5     BX03
# 197          Bronx  2010                 5     BX05
# 198          Bronx  2010                 5     BX06
# 199          Bronx  2010                 5     BX07
# ..             ...   ...               ...      ...
# 385  Staten Island  2010                85     SI37
# 386  Staten Island  2010                85     SI45
# 387  Staten Island  2010                85     SI48
# 388  Staten Island  2010                85     SI54
# 389  Staten Island  2010                85     SI99
#
#                             Neighborhood  Population
# 195               Claremont-Bathgate, NY       31078
# 196  Eastchester-Edenwald-Baychester, NY       34517
# 197       Bedford Park-Fordham North, NY       54415
# 198                          Belmont, NY       27378
# 199                        Bronxdale, NY       35538
# ..                                   ...         ...
# 385               Stapleton-Rosebank, NY       26453
# 386           New Dorp-Midland Beach, NY       21896
# 387                    Arden Heights, NY       25238
# 388                      Great Kills, NY       40720
# 389  park-cemetery-etc-Staten Island, NY           0
#
# [195 rows x 6 columns]

# %%
df_city_counts=pd.merge(df_city_counts,df_pop_2010,on='Neighborhood',how='left')

# %%
df_city_counts['Population_x']=df_city_counts['Population_y']
df_city_counts.head()
# Out:
#         Neighborhood  Count_of_Evictions Latitude Longitude  Population_x  \
# 0          Bronx, NY               21190  40.8467  -73.8786           NaN
# 1       Brooklyn, NY               17364  40.6501  -73.9496           NaN
# 2       New York, NY                7987  40.7127   -74.006           NaN
# 3        Jamaica, NY                2108  40.6915  -73.8057       53751.0
# 4  Staten Island, NY                2046  40.5835  -74.1496           NaN
#
#   Borough    Year  FIPS County Code NTA Code  Population_y
# 0     NaN     NaN               NaN      NaN           NaN
# 1     NaN     NaN               NaN      NaN           NaN
# 2     NaN     NaN               NaN      NaN           NaN
# 3  Queens  2010.0              81.0     QN61       53751.0
# 4     NaN     NaN               NaN      NaN           NaN

# %%
df_city_counts.drop(['Borough','Year','FIPS County Code','NTA Code','Population_y'],axis=1,inplace=True)

# %%
df_city_counts.rename(columns={'Population_x':'Population'},inplace=True)

# %%
df_city_counts.head()
# Out:
#         Neighborhood  Count_of_Evictions Latitude Longitude  Population
# 0          Bronx, NY               21190  40.8467  -73.8786         NaN
# 1       Brooklyn, NY               17364  40.6501  -73.9496         NaN
# 2       New York, NY                7987  40.7127   -74.006         NaN
# 3        Jamaica, NY                2108  40.6915  -73.8057     53751.0
# 4  Staten Island, NY                2046  40.5835  -74.1496         NaN

# %%
#Uncomment to create new file. WARNING!!! Will replace existing file with an incomplete file.
#df_city_counts.to_csv('city counts and population.csv',index=0)

# %%
df_city_counts=pd.read_csv('city counts and population.csv')

# %%
df_city_counts
# Out:
#                Neighborhood  Count_of_Evictions   Latitude  Longitude  \
# 0                 Bronx, NY               21190  40.846651 -73.878594
# 1              Brooklyn, NY               17364  40.650104 -73.949582
# 2              New York, NY                7987  40.712728 -74.006015
# 3               Jamaica, NY                2108  40.691485 -73.805677
# 4         Staten Island, NY                2046  40.583456 -74.149605
# 5          Far Rockaway, NY                 960  40.605383 -73.755133
# 6              Flushing, NY                 870  40.765430 -73.817429
# 7                Corona, NY                 656  40.746959 -73.860146
# 8               Astoria, NY                 563  40.772015 -73.930267
# 9             Ridgewood, NY                 427  40.708056 -73.914167
# 10       Queens Village, NY                 413  40.726769 -73.741521
# 11              Arverne, NY                 359  40.593417 -73.789546
# 12           Ozone Park, NY                 355  40.676770 -73.843746
# 13             Elmhurst, NY                 343  40.736580 -73.878393
# 14  Springfield Gardens, NY                 327  40.678159 -73.746521
# 15      Jackson Heights, NY                 319  40.755656 -73.885775
# 16             Woodside, NY                 305  40.745380 -73.905415
# 17         Saint Albans, NY                 295  40.698436 -73.760688
# 18     South Ozone Park, NY                 272  40.670103 -73.819023
# 19               Hollis, NY                 251  40.713436 -73.767077
# 20        Fresh Meadows, NY                 235  40.734825 -73.793467
# 21             Rosedale, NY                 230  40.662048 -73.735410
# 22        Richmond Hill, NY                 216  40.699425 -73.830967
# 23  South Richmond Hill, NY                 212  40.699425 -73.830967
# 24         Forest Hills, NY                 208  40.719594 -73.844855
# 25            Woodhaven, NY                 200  40.689270 -73.857913
# 26     Long Island City, NY                 198  40.741509 -73.956975
# 27        East Elmhurst, NY                 191  40.761212 -73.865136
# 28            Rego Park, NY                 188  40.722937 -73.862207
# 29          Kew Gardens, NY                 151  40.713941 -73.830742
# 30            Sunnyside, NY                 141  40.739824 -73.935415
# 31        Rockaway Park, NY                 135  40.580510 -73.836154
# 32        College Point, NY                 122  40.787601 -73.845968
# 33              Maspeth, NY                 119  40.723158 -73.912637
# 34              Bayside, NY                 110  40.768435 -73.777077
# 35      Cambria Heights, NY                  95  40.694547 -73.738465
# 36         Howard Beach, NY                  92  40.657882 -73.836246
# 37       Middle Village, NY                  72  40.718215 -73.878671
# 38      Oakland Gardens, NY                  64  40.753991 -73.765966
# 39           Whitestone, NY                  61  40.794546 -73.818467
# 40            Bellerose, NY                  40  40.724269 -73.715131
# 41          Little Neck, NY                  32  40.774534 -73.741256
# 42            Glen Oaks, NY                  16  40.747046 -73.711520
# 43        New Hyde Park, NY                   8  40.730845 -73.680550
# 44          Floral Park, NY                   5  40.724700 -73.704802
# 45            Roosevelt, NY                   2  40.678117 -73.585538
# 46          Carle Place, NY                   1  40.749273 -73.603751
# 47           Great Neck, NY                   1  40.800657 -73.728465
#
#     Population
# 0      1385108
# 1      2504701
# 2      1585873
# 3        53751
# 4       468730
# 5        60035
# 6        72008
# 7        57658
# 8        78793
# 9        69317
# 10       52504
# 11       11510
# 12       21376
# 13       88427
# 14       18665
# 15      108152
# 16       45099
# 17       48593
# 18       75878
# 19       20269
# 20       17812
# 21       25063
# 22       62982
# 23       49306
# 24       83728
# 25       56674
# 26       20030
# 27       23150
# 28       28260
# 29       23278
# 30       63271
# 31       21354
# 32       24275
# 33       30516
# 34       43808
# 35       18677
# 36       26148
# 37       37929
# 38       28237
# 39       30773
# 40       25287
# 41       26148
# 42       29506
# 43        9712
# 44       15863
# 45       16258
# 46        4981
# 47        9989

# %%
df_city_counts['Evictions per Capita']=''

# %%
df_city_counts['Evictions per Capita']=(df_city_counts['Count_of_Evictions']*1000)/df_city_counts['Population']

# %%
df_city_counts
# Out:
#                Neighborhood  Count_of_Evictions   Latitude  Longitude  \
# 0                 Bronx, NY               21190  40.846651 -73.878594
# 1              Brooklyn, NY               17364  40.650104 -73.949582
# 2              New York, NY                7987  40.712728 -74.006015
# 3               Jamaica, NY                2108  40.691485 -73.805677
# 4         Staten Island, NY                2046  40.583456 -74.149605
# 5          Far Rockaway, NY                 960  40.605383 -73.755133
# 6              Flushing, NY                 870  40.765430 -73.817429
# 7                Corona, NY                 656  40.746959 -73.860146
# 8               Astoria, NY                 563  40.772015 -73.930267
# 9             Ridgewood, NY                 427  40.708056 -73.914167
# 10       Queens Village, NY                 413  40.726769 -73.741521
# 11              Arverne, NY                 359  40.593417 -73.789546
# 12           Ozone Park, NY                 355  40.676770 -73.843746
# 13             Elmhurst, NY                 343  40.736580 -73.878393
# 14  Springfield Gardens, NY                 327  40.678159 -73.746521
# 15      Jackson Heights, NY                 319  40.755656 -73.885775
# 16             Woodside, NY                 305  40.745380 -73.905415
# 17         Saint Albans, NY                 295  40.698436 -73.760688
# 18     South Ozone Park, NY                 272  40.670103 -73.819023
# 19               Hollis, NY                 251  40.713436 -73.767077
# 20        Fresh Meadows, NY                 235  40.734825 -73.793467
# 21             Rosedale, NY                 230  40.662048 -73.735410
# 22        Richmond Hill, NY                 216  40.699425 -73.830967
# 23  South Richmond Hill, NY                 212  40.699425 -73.830967
# 24         Forest Hills, NY                 208  40.719594 -73.844855
# 25            Woodhaven, NY                 200  40.689270 -73.857913
# 26     Long Island City, NY                 198  40.741509 -73.956975
# 27        East Elmhurst, NY                 191  40.761212 -73.865136
# 28            Rego Park, NY                 188  40.722937 -73.862207
# 29          Kew Gardens, NY                 151  40.713941 -73.830742
# 30            Sunnyside, NY                 141  40.739824 -73.935415
# 31        Rockaway Park, NY                 135  40.580510 -73.836154
# 32        College Point, NY                 122  40.787601 -73.845968
# 33              Maspeth, NY                 119  40.723158 -73.912637
# 34              Bayside, NY                 110  40.768435 -73.777077
# 35      Cambria Heights, NY                  95  40.694547 -73.738465
# 36         Howard Beach, NY                  92  40.657882 -73.836246
# 37       Middle Village, NY                  72  40.718215 -73.878671
# 38      Oakland Gardens, NY                  64  40.753991 -73.765966
# 39           Whitestone, NY                  61  40.794546 -73.818467
# 40            Bellerose, NY                  40  40.724269 -73.715131
# 41          Little Neck, NY                  32  40.774534 -73.741256
# 42            Glen Oaks, NY                  16  40.747046 -73.711520
# 43        New Hyde Park, NY                   8  40.730845 -73.680550
# 44          Floral Park, NY                   5  40.724700 -73.704802
# 45            Roosevelt, NY                   2  40.678117 -73.585538
# 46          Carle Place, NY                   1  40.749273 -73.603751
# 47           Great Neck, NY                   1  40.800657 -73.728465
#
#     Population  Evictions per Capita
# 0      1385108             15.298446
# 1      2504701              6.932564
# 2      1585873              5.036343
# 3        53751             39.217875
# 4       468730              4.364986
# 5        60035             15.990672
# 6        72008             12.081991
# 7        57658             11.377432
# 8        78793              7.145305
# 9        69317              6.160105
# 10       52504              7.866067
# 11       11510             31.190269
# 12       21376             16.607410
# 13       88427              3.878906
# 14       18665             17.519421
# 15      108152              2.949552
# 16       45099              6.762899
# 17       48593              6.070833
# 18       75878              3.584702
# 19       20269             12.383443
# 20       17812             13.193353
# 21       25063              9.176874
# 22       62982              3.429551
# 23       49306              4.299680
# 24       83728              2.484235
# 25       56674              3.528955
# 26       20030              9.885172
# 27       23150              8.250540
# 28       28260              6.652512
# 29       23278              6.486812
# 30       63271              2.228509
# 31       21354              6.322001
# 32       24275              5.025747
# 33       30516              3.899594
# 34       43808              2.510957
# 35       18677              5.086470
# 36       26148              3.518434
# 37       37929              1.898284
# 38       28237              2.266530
# 39       30773              1.982257
# 40       25287              1.581840
# 41       26148              1.223803
# 42       29506              0.542263
# 43        9712              0.823723
# 44       15863              0.315199
# 45       16258              0.123016
# 46        4981              0.200763
# 47        9989              0.100110

# %% [markdown]
# This dataframe has all the information necessary to plot a map. Let's create a copy and save it as a separate csv, just in case.

# %%
df_evictions_map=df_city_counts.copy()
df_evictions_map.to_csv('mapping_data.csv',index=0)

# %%
df_evictions_map=pd.read_csv('mapping_data.csv')
df_evictions_map
# Out:
#                Neighborhood  Count_of_Evictions   Latitude  Longitude  \
# 0                 Bronx, NY               21190  40.846651 -73.878594
# 1              Brooklyn, NY               17364  40.650104 -73.949582
# 2              New York, NY                7987  40.712728 -74.006015
# 3               Jamaica, NY                2108  40.691485 -73.805677
# 4         Staten Island, NY                2046  40.583456 -74.149605
# 5          Far Rockaway, NY                 960  40.605383 -73.755133
# 6              Flushing, NY                 870  40.765430 -73.817429
# 7                Corona, NY                 656  40.746959 -73.860146
# 8               Astoria, NY                 563  40.772014 -73.930267
# 9             Ridgewood, NY                 427  40.708056 -73.914167
# 10       Queens Village, NY                 413  40.726769 -73.741521
# 11              Arverne, NY                 359  40.593417 -73.789546
# 12           Ozone Park, NY                 355  40.676770 -73.843746
# 13             Elmhurst, NY                 343  40.736580 -73.878393
# 14  Springfield Gardens, NY                 327  40.678159 -73.746521
# 15      Jackson Heights, NY                 319  40.755656 -73.885775
# 16             Woodside, NY                 305  40.745380 -73.905415
# 17         Saint Albans, NY                 295  40.698436 -73.760688
# 18     South Ozone Park, NY                 272  40.670104 -73.819023
# 19               Hollis, NY                 251  40.713436 -73.767077
# 20        Fresh Meadows, NY                 235  40.734825 -73.793467
# 21             Rosedale, NY                 230  40.662048 -73.735410
# 22        Richmond Hill, NY                 216  40.699425 -73.830967
# 23  South Richmond Hill, NY                 212  40.699425 -73.830967
# 24         Forest Hills, NY                 208  40.719594 -73.844855
# 25            Woodhaven, NY                 200  40.689270 -73.857913
# 26     Long Island City, NY                 198  40.741509 -73.956975
# 27        East Elmhurst, NY                 191  40.761212 -73.865136
# 28            Rego Park, NY                 188  40.722937 -73.862207
# 29          Kew Gardens, NY                 151  40.713941 -73.830742
# 30            Sunnyside, NY                 141  40.739824 -73.935415
# 31        Rockaway Park, NY                 135  40.580510 -73.836154
# 32        College Point, NY                 122  40.787601 -73.845968
# 33              Maspeth, NY                 119  40.723158 -73.912637
# 34              Bayside, NY                 110  40.768435 -73.777077
# 35      Cambria Heights, NY                  95  40.694547 -73.738465
# 36         Howard Beach, NY                  92  40.657882 -73.836246
# 37       Middle Village, NY                  72  40.718215 -73.878671
# 38      Oakland Gardens, NY                  64  40.753991 -73.765966
# 39           Whitestone, NY                  61  40.794546 -73.818467
# 40            Bellerose, NY                  40  40.724269 -73.715131
# 41          Little Neck, NY                  32  40.774534 -73.741256
# 42            Glen Oaks, NY                  16  40.747046 -73.711520
# 43        New Hyde Park, NY                   8  40.730845 -73.680550
# 44          Floral Park, NY                   5  40.724700 -73.704802
# 45            Roosevelt, NY                   2  40.678117 -73.585538
# 46          Carle Place, NY                   1  40.749273 -73.603751
# 47           Great Neck, NY                   1  40.800657 -73.728465
#
#     Population  Evictions per Capita
# 0      1385108             15.298446
# 1      2504701              6.932564
# 2      1585873              5.036343
# 3        53751             39.217875
# 4       468730              4.364986
# 5        60035             15.990672
# 6        72008             12.081991
# 7        57658             11.377432
# 8        78793              7.145305
# 9        69317              6.160105
# 10       52504              7.866067
# 11       11510             31.190269
# 12       21376             16.607410
# 13       88427              3.878906
# 14       18665             17.519421
# 15      108152              2.949552
# 16       45099              6.762899
# 17       48593              6.070833
# 18       75878              3.584702
# 19       20269             12.383443
# 20       17812             13.193353
# 21       25063              9.176874
# 22       62982              3.429551
# 23       49306              4.299680
# 24       83728              2.484235
# 25       56674              3.528955
# 26       20030              9.885172
# 27       23150              8.250540
# 28       28260              6.652512
# 29       23278              6.486812
# 30       63271              2.228509
# 31       21354              6.322001
# 32       24275              5.025747
# 33       30516              3.899594
# 34       43808              2.510957
# 35       18677              5.086470
# 36       26148              3.518434
# 37       37929              1.898284
# 38       28237              2.266530
# 39       30773              1.982257
# 40       25287              1.581840
# 41       26148              1.223803
# 42       29506              0.542263
# 43        9712              0.823723
# 44       15863              0.315199
# 45       16258              0.123016
# 46        4981              0.200763
# 47        9989              0.100110

# %%
df_evictions_map.dtypes
# Out:
# Neighborhood             object
# Count_of_Evictions        int64
# Latitude                float64
# Longitude               float64
# Population                int64
# Evictions per Capita    float64
# dtype: object

# %%
evictions_rate_map=folium.Map(location=[lat-0.1,lon],zoom_start=11) #create a map. 0.1 is the offset to center the map.

# %%
#use zip to create a list of information to add to the map.
#add feature group

for lat, lon, neighborhood,evictions_per_capita in zip(df_evictions_map['Latitude'], df_evictions_map['Longitude'], df_evictions_map['Neighborhood'],df_evictions_map['Evictions per Capita']):
    label = 'Neighborhood: {}, \nEvictions per Capita: {:.2f}'.format(neighborhood,evictions_per_capita)
    popup_label = folium.Popup(label, parse_html=True)
    folium.Circle(
    [lat, lon],
    radius=evictions_per_capita*120,
    popup=popup_label,
    color='orange',
    line_width=1,
    fill=True,
    fill_color='red',
    fill_opacity=0.5,
    parse_html=False).add_to(evictions_rate_map)  
    
evictions_rate_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We can save the map as html.

# %%
evictions_rate_map.save('NYC_Evictions.html')

# %%
df_city_counts.sort_values(by='Evictions per Capita',ascending=False,inplace=True)
df_city_top10=df_city_counts.head(10)
df_city_bottom10=df_city_counts.tail(10)

# %%
df_city_top10
# Out:
#                Neighborhood  Count_of_Evictions   Latitude  Longitude  \
# 3               Jamaica, NY                2108  40.691485 -73.805677
# 11              Arverne, NY                 359  40.593417 -73.789546
# 14  Springfield Gardens, NY                 327  40.678159 -73.746521
# 12           Ozone Park, NY                 355  40.676770 -73.843746
# 5          Far Rockaway, NY                 960  40.605383 -73.755133
# 0                 Bronx, NY               21190  40.846651 -73.878594
# 20        Fresh Meadows, NY                 235  40.734825 -73.793467
# 19               Hollis, NY                 251  40.713436 -73.767077
# 6              Flushing, NY                 870  40.765430 -73.817429
# 7                Corona, NY                 656  40.746959 -73.860146
#
#     Population  Evictions per Capita
# 3        53751             39.217875
# 11       11510             31.190269
# 14       18665             17.519421
# 12       21376             16.607410
# 5        60035             15.990672
# 0      1385108             15.298446
# 20       17812             13.193353
# 19       20269             12.383443
# 6        72008             12.081991
# 7        57658             11.377432

# %%
df_city_bottom10
# Out:
#           Neighborhood  Count_of_Evictions   Latitude  Longitude  Population  \
# 39      Whitestone, NY                  61  40.794546 -73.818467       30773
# 37  Middle Village, NY                  72  40.718215 -73.878671       37929
# 40       Bellerose, NY                  40  40.724269 -73.715131       25287
# 41     Little Neck, NY                  32  40.774534 -73.741256       26148
# 43   New Hyde Park, NY                   8  40.730845 -73.680550        9712
# 42       Glen Oaks, NY                  16  40.747046 -73.711520       29506
# 44     Floral Park, NY                   5  40.724700 -73.704802       15863
# 46     Carle Place, NY                   1  40.749273 -73.603751        4981
# 45       Roosevelt, NY                   2  40.678117 -73.585538       16258
# 47      Great Neck, NY                   1  40.800657 -73.728465        9989
#
#     Evictions per Capita
# 39              1.982257
# 37              1.898284
# 40              1.581840
# 41              1.223803
# 43              0.823723
# 42              0.542263
# 44              0.315199
# 46              0.200763
# 45              0.123016
# 47              0.100110

# %%
labels=df_city_top10['Neighborhood']

plt.rcdefaults()
fig,ax=plt.subplots()
y_pos=np.arange(len(labels))

ax.barh(y_pos,df_city_top10['Evictions per Capita'],align='center',color='crimson')
ax.set_yticks(y_pos)
ax.set_yticklabels(labels)
ax.invert_yaxis()
ax.set_xlabel('Evictions per Capita')
ax.set_title('Ten New York City Neighborhoods With Most Evictions Per Capita')

plt.show()

# %%
labels=df_city_bottom10['Neighborhood']

plt.rcdefaults()
fig,ax=plt.subplots()
y_pos=np.arange(len(labels))

ax.barh(y_pos,df_city_bottom10['Evictions per Capita'],align='center',color='crimson')
ax.set_yticks(y_pos)
ax.set_yticklabels(labels)
ax.set_xlabel('Evictions per Capita')
ax.set_title('Ten New York City Neighborhoods With Lowest Evictions Per Capita')

plt.show()
