# %%
import requests
import pandas as pd
import json
import matplotlib.pyplot as plt

# %% [markdown]
# Use API from The Covid Tracking Project to retrieve data

# %%
response=requests.get('https://covidtracking.com/api/v1/states/daily.csv')

# %% [markdown]
# Using python write method to save data in a new csv file.

# %%
with open('covid19_historic_all_states.csv','w') as f:
    f.write(response.text)
f.close()

# %%
df=pd.read_csv('covid19_historic_all_states.csv')

# %%
df.columns.values
# Out:
# array(['date', 'state', 'positive', 'negative', 'pending',
#        'hospitalizedCurrently', 'hospitalizedCumulative',
#        'inIcuCurrently', 'inIcuCumulative', 'onVentilatorCurrently',
#        'onVentilatorCumulative', 'recovered', 'dataQualityGrade',
#        'lastUpdateEt', 'dateModified', 'checkTimeEt', 'death',
#        'hospitalized', 'dateChecked', 'totalTestsViral',
#        'positiveTestsViral', 'negativeTestsViral', 'positiveCasesViral',
#        'fips', 'positiveIncrease', 'negativeIncrease', 'total',
#        'totalTestResults', 'totalTestResultsIncrease', 'posNeg',
#        'deathIncrease', 'hospitalizedIncrease', 'hash', 'commercialScore',
#        'negativeRegularScore', 'negativeScore', 'positiveScore', 'score',
#        'grade'], dtype=object)

# %%
df[['date','state','positive','negative','recovered','dateModified','checkTimeEt','death','dateChecked','total','totalTestResults','totalTestResultsIncrease','posNeg','deathIncrease']].head()
# Out:
#        date state  positive  negative  recovered          dateModified  \
# 0  20200705    AK    1111.0  121621.0      544.0  2020-07-04T00:00:00Z
# 1  20200705    AL   43953.0  405933.0    22082.0  2020-07-05T11:00:00Z
# 2  20200705    AR   23209.0  315684.0    16726.0  2020-07-05T00:00:00Z
# 3  20200705    AS       0.0     696.0        NaN  2020-07-01T00:00:00Z
# 4  20200705    AZ   98089.0  506273.0    11361.0  2020-07-05T00:00:00Z
#
#    checkTimeEt   death           dateChecked   total  totalTestResults  \
# 0  07/03 20:00    16.0  2020-07-04T00:00:00Z  122732            122732
# 1  07/05 07:00  1007.0  2020-07-05T11:00:00Z  449886            449886
# 2  07/04 20:00   286.0  2020-07-05T00:00:00Z  338893            338893
# 3  06/30 20:00     0.0  2020-07-01T00:00:00Z     696               696
# 4  07/04 20:00  1809.0  2020-07-05T00:00:00Z  604362            604362
#
#    totalTestResultsIncrease  posNeg  deathIncrease
# 0                         0  122732              0
# 1                      7798  449886              0
# 2                         0  338893              0
# 3                         0     696              0
# 4                     14854  604362              4

# %%
df_covid19=df[['date','state','positive','negative','recovered','dateModified','checkTimeEt','death','dateChecked','total','totalTestResults','totalTestResultsIncrease']].copy(deep=True)

# %%
df_covid19.head()
# Out:
#        date state  positive  negative  recovered          dateModified  \
# 0  20200705    AK    1111.0  121621.0      544.0  2020-07-04T00:00:00Z
# 1  20200705    AL   43953.0  405933.0    22082.0  2020-07-05T11:00:00Z
# 2  20200705    AR   23209.0  315684.0    16726.0  2020-07-05T00:00:00Z
# 3  20200705    AS       0.0     696.0        NaN  2020-07-01T00:00:00Z
# 4  20200705    AZ   98089.0  506273.0    11361.0  2020-07-05T00:00:00Z
#
#    checkTimeEt   death           dateChecked   total  totalTestResults  \
# 0  07/03 20:00    16.0  2020-07-04T00:00:00Z  122732            122732
# 1  07/05 07:00  1007.0  2020-07-05T11:00:00Z  449886            449886
# 2  07/04 20:00   286.0  2020-07-05T00:00:00Z  338893            338893
# 3  06/30 20:00     0.0  2020-07-01T00:00:00Z     696               696
# 4  07/04 20:00  1809.0  2020-07-05T00:00:00Z  604362            604362
#
#    totalTestResultsIncrease
# 0                         0
# 1                      7798
# 2                         0
# 3                         0
# 4                     14854

# %%
df_covid19['Total - TotalTestResults']=df_covid19['total']-df_covid19['totalTestResults']

# %%
df_covid19.sort_values(by=['state','date'],ascending=True,inplace=True)
df_covid19.head()
# Out:
#           date state  positive  negative  recovered dateModified checkTimeEt  \
# 6726  20200306    AK       0.0       8.0        NaN          NaN         NaN
# 6676  20200307    AK       0.0      12.0        NaN          NaN         NaN
# 6626  20200308    AK       0.0      14.0        NaN          NaN         NaN
# 6576  20200309    AK       0.0      23.0        NaN          NaN         NaN
# 6526  20200310    AK       0.0      23.0        NaN          NaN         NaN
#
#       death dateChecked  total  totalTestResults  totalTestResultsIncrease  \
# 6726    0.0         NaN      9                 8                         0
# 6676    0.0         NaN     14                12                         4
# 6626    0.0         NaN     20                14                         2
# 6576    0.0         NaN     32                23                         9
# 6526    0.0         NaN     32                23                         0
#
#       Total - TotalTestResults
# 6726                         1
# 6676                         2
# 6626                         6
# 6576                         9
# 6526                         9

# %%
df_covid19.to_csv('covid19_by_state.csv',index=0)

# %%
df_covid19=pd.read_csv('covid19_by_state.csv')
df_covid19.head()
# Out:
#        date state  positive  negative  recovered dateModified checkTimeEt  \
# 0  20200306    AK       0.0       8.0        NaN          NaN         NaN
# 1  20200307    AK       0.0      12.0        NaN          NaN         NaN
# 2  20200308    AK       0.0      14.0        NaN          NaN         NaN
# 3  20200309    AK       0.0      23.0        NaN          NaN         NaN
# 4  20200310    AK       0.0      23.0        NaN          NaN         NaN
#
#    death dateChecked  total  totalTestResults  totalTestResultsIncrease  \
# 0    0.0         NaN      9                 8                         0
# 1    0.0         NaN     14                12                         4
# 2    0.0         NaN     20                14                         2
# 3    0.0         NaN     32                23                         9
# 4    0.0         NaN     32                23                         0
#
#    Total - TotalTestResults
# 0                         1
# 1                         2
# 2                         6
# 3                         9
# 4                         9

# %%
df_covid19_FL=df_covid19[df_covid19['state']=='FL'].copy(deep=True)
df_covid19_FL.head()
# Out:
#           date state  positive  negative  recovered dateModified checkTimeEt  \
# 1214  20200304    FL       2.0      24.0        NaN          NaN         NaN
# 1215  20200305    FL       9.0      31.0        NaN          NaN         NaN
# 1216  20200306    FL       9.0      55.0        NaN          NaN         NaN
# 1217  20200307    FL      14.0     100.0        NaN          NaN         NaN
# 1218  20200308    FL      17.0     118.0        NaN          NaN         NaN
#
#       death dateChecked  total  totalTestResults  totalTestResultsIncrease  \
# 1214    NaN         NaN     42                26                         0
# 1215    NaN         NaN    109                40                        14
# 1216    NaN         NaN    115                64                        24
# 1217    NaN         NaN    202               114                        50
# 1218    NaN         NaN    243               135                        21
#
#       Total - TotalTestResults
# 1214                        16
# 1215                        69
# 1216                        51
# 1217                        88
# 1218                       108

# %% [markdown]
# The percentage of test results that were positive for covid19 can be represented by a plot of number of positive results to total number of test results as shown below. Each dot represents a day.

# %%
df_covid19_FL.plot(x='totalTestResults',y='positive',kind='scatter',figsize=(15,8))

# %%
df_covid19_FL[['date_test']]=df_covid19_FL[['date']]
df_covid19_FL.head()
# Out:
#           date state  positive  negative  recovered dateModified checkTimeEt  \
# 1214  20200304    FL       2.0      24.0        NaN          NaN         NaN
# 1215  20200305    FL       9.0      31.0        NaN          NaN         NaN
# 1216  20200306    FL       9.0      55.0        NaN          NaN         NaN
# 1217  20200307    FL      14.0     100.0        NaN          NaN         NaN
# 1218  20200308    FL      17.0     118.0        NaN          NaN         NaN
#
#       death dateChecked  total  totalTestResults  totalTestResultsIncrease  \
# 1214    NaN         NaN     42                26                         0
# 1215    NaN         NaN    109                40                        14
# 1216    NaN         NaN    115                64                        24
# 1217    NaN         NaN    202               114                        50
# 1218    NaN         NaN    243               135                        21
#
#       Total - TotalTestResults  date_test
# 1214                        16   20200304
# 1215                        69   20200305
# 1216                        51   20200306
# 1217                        88   20200307
# 1218                       108   20200308

# %%
df_covid19_FL['date']=pd.to_datetime(df_covid19_FL['date_test'],format="%Y%m%d")

# %%
df_covid19_FL.dtypes
# Out:
# date                        datetime64[ns]
# state                               object
# positive                           float64
# negative                           float64
# recovered                          float64
# dateModified                        object
# checkTimeEt                         object
# death                              float64
# dateChecked                         object
# total                                int64
# totalTestResults                     int64
# totalTestResultsIncrease             int64
# Total - TotalTestResults             int64
# date_test                            int64
# dtype: object

# %%
df_covid19_FL.head()
# Out:
#            date state  positive  negative  recovered dateModified checkTimeEt  \
# 1214 2020-03-04    FL       2.0      24.0        NaN          NaN         NaN
# 1215 2020-03-05    FL       9.0      31.0        NaN          NaN         NaN
# 1216 2020-03-06    FL       9.0      55.0        NaN          NaN         NaN
# 1217 2020-03-07    FL      14.0     100.0        NaN          NaN         NaN
# 1218 2020-03-08    FL      17.0     118.0        NaN          NaN         NaN
#
#       death dateChecked  total  totalTestResults  totalTestResultsIncrease  \
# 1214    NaN         NaN     42                26                         0
# 1215    NaN         NaN    109                40                        14
# 1216    NaN         NaN    115                64                        24
# 1217    NaN         NaN    202               114                        50
# 1218    NaN         NaN    243               135                        21
#
#       Total - TotalTestResults  date_test
# 1214                        16   20200304
# 1215                        69   20200305
# 1216                        51   20200306
# 1217                        88   20200307
# 1218                       108   20200308

# %% [markdown]
# Let's plot the number of positive tests over the time.

# %%
df_covid19_FL.plot(x='date',y='positive',kind='line',figsize=(15,8))

# %%
df_covid19_FL.plot(x='date',y='totalTestResults',kind='line',figsize=(15,8))

# %%
df_covid19_FL.plot(x='date',y='Total - TotalTestResults',kind='line',figsize=(15,9))
