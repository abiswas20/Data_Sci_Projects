# %%
import requests
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
params={'format':'csv'}

# %%
response=requests.get('https://covidtracking.com/api/v1/states/daily.csv')

# %%
with open('covid19_historic_all_states.csv','w') as f:
    f.write(response.text)
f.close()

# %%
df=pd.read_csv('covid19_historic_all_states.csv')

# %%
df.head()
# Out:
#        date state  positive  negative  pending  hospitalizedCurrently  \
# 0  20200629    AK     904.0  107805.0      NaN                   16.0
# 1  20200629    AL   37175.0  356118.0      NaN                  715.0
# 2  20200629    AR   20257.0  282279.0      NaN                  300.0
# 3  20200629    AS       0.0     696.0      NaN                    NaN
# 4  20200629    AZ   74533.0  436890.0      NaN                 2721.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                     NaN             NaN              NaN
# 1                  2725.0             NaN            801.0
# 2                  1380.0             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                  4634.0           679.0              NaN
#
#    onVentilatorCurrently  ...    posNeg  deathIncrease hospitalizedIncrease  \
# 0                    1.0  ...    108709              0                    0
# 1                    NaN  ...    393293             10                   22
# 2                   63.0  ...    302536              6                    7
# 3                    NaN  ...       696              0                    0
# 4                  465.0  ...    511423              0                   17
#
#                                        hash commercialScore  \
# 0  a86a3dc4bfbba3e423434858dd4e5230e6ba9753               0
# 1  de21472ac462718d75201c8e93e01f28b9542e9f               0
# 2  6485f0b6af19d7d02d56b471d22c9095e38dd696               0
# 3  eb59d7d99c77b168f8869581b58a5fec9dc91f8d               0
# 4  7be4a47c695495c39660118ec049f17bb8199320               0
#
#   negativeRegularScore  negativeScore  positiveScore score  grade
# 0                    0              0              0     0    NaN
# 1                    0              0              0     0    NaN
# 2                    0              0              0     0    NaN
# 3                    0              0              0     0    NaN
# 4                    0              0              0     0    NaN
#
# [5 rows x 39 columns]

# %%
df.columns.values
# Out:
# array(['date', 'state', 'positive', 'negative', 'pending',
#        'hospitalizedCurrently', 'hospitalizedCumulative',
#        'inIcuCurrently', 'inIcuCumulative', 'onVentilatorCurrently',
#        'onVentilatorCumulative', 'recovered', 'dataQualityGrade',
#        'lastUpdateEt', 'dateModified', 'checkTimeEt', 'death',
#        'hospitalized', 'dateChecked', 'totalTestsViral',
#        'positiveTestsViral', 'negativeTestsViral', 'positiveCasesViral',
#        'fips', 'positiveIncrease', 'negativeIncrease', 'total',
#        'totalTestResults', 'totalTestResultsIncrease', 'posNeg',
#        'deathIncrease', 'hospitalizedIncrease', 'hash', 'commercialScore',
#        'negativeRegularScore', 'negativeScore', 'positiveScore', 'score',
#        'grade'], dtype=object)

# %%
df[['date','state','positive','negative','recovered','dateModified','checkTimeEt','death','dateChecked','total','totalTestResults','totalTestResultsIncrease','posNeg','deathIncrease']].head()
# Out:
#        date state  positive  negative  recovered          dateModified  \
# 0  20200629    AK     904.0  107805.0      525.0  2020-06-29T00:00:00Z
# 1  20200629    AL   37175.0  356118.0    18866.0  2020-06-29T11:00:00Z
# 2  20200629    AR   20257.0  282279.0    14066.0  2020-06-29T14:36:00Z
# 3  20200629    AS       0.0     696.0        NaN  2020-06-27T00:00:00Z
# 4  20200629    AZ   74533.0  436890.0     9179.0  2020-06-29T00:00:00Z
#
#    checkTimeEt   death           dateChecked   total  totalTestResults  \
# 0  06/28 20:00    14.0  2020-06-29T00:00:00Z  108709            108709
# 1  06/29 07:00   929.0  2020-06-29T11:00:00Z  393293            393293
# 2  06/29 10:36   265.0  2020-06-29T14:36:00Z  302536            302536
# 3  06/26 20:00     0.0  2020-06-27T00:00:00Z     696               696
# 4  06/28 20:00  1588.0  2020-06-29T00:00:00Z  511423            511423
#
#    totalTestResultsIncrease  posNeg  deathIncrease
# 0                       409  108709              0
# 1                      7013  393293             10
# 2                     11314  302536              6
# 3                         0     696              0
# 4                      1527  511423              0

# %%
df_covid19=df[['date','state','positive','negative','recovered','dateModified','checkTimeEt','death','dateChecked','total','totalTestResults','totalTestResultsIncrease']].copy(deep=True)

# %%
df_covid19.head()
# Out:
#        date state  positive  negative  recovered          dateModified  \
# 0  20200629    AK     904.0  107805.0      525.0  2020-06-29T00:00:00Z
# 1  20200629    AL   37175.0  356118.0    18866.0  2020-06-29T11:00:00Z
# 2  20200629    AR   20257.0  282279.0    14066.0  2020-06-29T14:36:00Z
# 3  20200629    AS       0.0     696.0        NaN  2020-06-27T00:00:00Z
# 4  20200629    AZ   74533.0  436890.0     9179.0  2020-06-29T00:00:00Z
#
#    checkTimeEt   death           dateChecked   total  totalTestResults  \
# 0  06/28 20:00    14.0  2020-06-29T00:00:00Z  108709            108709
# 1  06/29 07:00   929.0  2020-06-29T11:00:00Z  393293            393293
# 2  06/29 10:36   265.0  2020-06-29T14:36:00Z  302536            302536
# 3  06/26 20:00     0.0  2020-06-27T00:00:00Z     696               696
# 4  06/28 20:00  1588.0  2020-06-29T00:00:00Z  511423            511423
#
#    totalTestResultsIncrease
# 0                       409
# 1                      7013
# 2                     11314
# 3                         0
# 4                      1527

# %%
df_covid19['Total - TotalTestResults']=df_covid19['total']-df_covid19['totalTestResults']

# %%
df_covid19['Total - TotalTestResults'].unique()
# Out:
# array([    0,  1744,   261,    31,   158,  1726,   295,   146,  1731,
#          284,   140,  1752,    12,   142,  1675,   303,    21,   134,
#         1535,   319,    35,   160,  1425,   291,    33,  1546,   298,
#           15,   169,  1625,   297,     9,   153,  1630,    20,   155,
#         1578,   285,    11,  1457,   259,    13,   174,  1240,   313,
#          179,  1150,   257,     5,   192,  1167,   188,  1184,   302,
#            2,   184,  1241,   283,     7,   167,  1242,   363,     6,
#          172,   358,    28,  1134,   407,   190,  1100,   383,     4,
#         1024,   373,     3,   206,  1161,   385,   183,  1265,   350,
#          177,  1193,   374,     8,  1221,  1643,   412,   196,  1191,
#          435,   199,  1206,  2183,   450,   209,  1160,  1661,   419,
#          211,  1332,  1208,   500,    19,   960,   481,   208,  1308,
#          891,   525,   235,  1158,   476,    22,   250,   955,  1370,
#          444,   335,   901,    18,   218,   988,  1714,   414,    45,
#          207,  1337,  1844,   411,   223,  1563,   409,  1487,  1526,
#          464,   187,  1471,  1434,   490,    26,   220,  1357,   861,
#          518,  1369,   874,   473,    17,  1346,  1481,   530,   194,
#         1479,  1216,   527,   182,  1676,  1401,   485,    37,   189,
#         1228,   543,   458,   191,   735,   496,    51,    62,  1064,
#           54,   447,    58,   180,  1080,   432,    36,   512,   591,
#          506,    39,  1452,   304,   557,   501,   204,  1433,   532,
#          553,   549,  1499,   345,   552,   519,   219,  1351,    79,
#          594,   469,   212,   550,    34,   236,  1181,   244,   647,
#          478,   226,  1226,   641,   465,    29,   231,   159,   676,
#          583,   468,    68,  1187,   272,    43,   195,  1252,    81,
#          617,  1940,   620,    78,   227,   560,    57,   193,  1099,
#          270,   542,  1183,   539,   197,  1292,   398,  1405,   241,
#         1287,   424,   487,  1301,   265,  1951,   492,   201,  1258,
#          225,  1954,   477,   229,  1203,  1761,  1104,  1895,   237,
#         7200,  1179,   316,  1839,   499,   248,  1760,     1,   486,
#         1285,  1478,   198, 13200,  1325,   121,  1465,   537,  1335,
#         1410,   280,  1275,    25,  1322,    23,   277,  1789,   125,
#         1288,   273,  1297,   119,  1251,   521,  1418,    93,   517,
#        13900,  1411,  1392, 14100,  1395,   143,  1304,   627,    42,
#        14600,  1324,    89,  1407,    49,   968, 15000,  1142,    10,
#          101,  1000,  1129,  1039, 13000,  1281,    94, 59500,  1225,
#          114,  1055,    56,   126,  1119, 57400,  1235,    97,   897,
#           24,  1163,    65,   854, 64400,   144,   794,   817,   296,
#          792,   138,    55,    30,  1517,   592,   334,  1443,   712,
#          181,    53, 48600,  1233,   804,    70,   268, 12100,  1008,
#          869,    77,   860,   889,   102,   216,    87,   963,   959,
#           69,   154,   122,  1002,   942,    40,   433,    71,   290,
#          203,  1026,   631,    86,    52,   113,   130,  1019,    74,
#          437,    50,   954,   110,   361,    14,    41,    66,   872,
#           82,   149,    63,    32,   514,   151,    95,    46,   454,
#          164,   221,    80,   157,   150,    92,   147,    76,    27,
#           16,    67,   115,    44,   108,    60,    88])

# %%
df_covid19.sort_values(by=['state','date'],ascending=True,inplace=True)
df_covid19.head()
# Out:
#           date state  positive  negative  recovered dateModified checkTimeEt  \
# 6390  20200306    AK       0.0       8.0        NaN          NaN         NaN
# 6340  20200307    AK       0.0      12.0        NaN          NaN         NaN
# 6290  20200308    AK       0.0      14.0        NaN          NaN         NaN
# 6240  20200309    AK       0.0      23.0        NaN          NaN         NaN
# 6190  20200310    AK       0.0      23.0        NaN          NaN         NaN
#
#       death dateChecked  total  totalTestResults  totalTestResultsIncrease  \
# 6390    0.0         NaN      9                 8                         0
# 6340    0.0         NaN     14                12                         4
# 6290    0.0         NaN     20                14                         2
# 6240    0.0         NaN     32                23                         9
# 6190    0.0         NaN     32                23                         0
#
#       Total - TotalTestResults
# 6390                         1
# 6340                         2
# 6290                         6
# 6240                         9
# 6190                         9

# %%
df_covid19.to_csv('covid19_by_state.csv',index=0)

# %%
df_covid19=pd.read_csv('covid19_by_state.csv')
df_covid19.head()
# Out:
#        date state  positive  negative  recovered dateModified checkTimeEt  \
# 0  20200306    AK       0.0       8.0        NaN          NaN         NaN
# 1  20200307    AK       0.0      12.0        NaN          NaN         NaN
# 2  20200308    AK       0.0      14.0        NaN          NaN         NaN
# 3  20200309    AK       0.0      23.0        NaN          NaN         NaN
# 4  20200310    AK       0.0      23.0        NaN          NaN         NaN
#
#    death dateChecked  total  totalTestResults  totalTestResultsIncrease  \
# 0    0.0         NaN      9                 8                         0
# 1    0.0         NaN     14                12                         4
# 2    0.0         NaN     20                14                         2
# 3    0.0         NaN     32                23                         9
# 4    0.0         NaN     32                23                         0
#
#    Total - TotalTestResults
# 0                         1
# 1                         2
# 2                         6
# 3                         9
# 4                         9

# %%
df_covid19_FL=df_covid19[df_covid19['state']=='FL'].copy(deep=True)
df_covid19_FL.head()
# Out:
#           date state  positive  negative  recovered dateModified checkTimeEt  \
# 1154  20200304    FL       2.0      24.0        NaN          NaN         NaN
# 1155  20200305    FL       9.0      31.0        NaN          NaN         NaN
# 1156  20200306    FL       9.0      55.0        NaN          NaN         NaN
# 1157  20200307    FL      14.0     100.0        NaN          NaN         NaN
# 1158  20200308    FL      17.0     118.0        NaN          NaN         NaN
#
#       death dateChecked  total  totalTestResults  totalTestResultsIncrease  \
# 1154    NaN         NaN     42                26                         0
# 1155    NaN         NaN    109                40                        14
# 1156    NaN         NaN    115                64                        24
# 1157    NaN         NaN    202               114                        50
# 1158    NaN         NaN    243               135                        21
#
#       Total - TotalTestResults
# 1154                        16
# 1155                        69
# 1156                        51
# 1157                        88
# 1158                       108

# %%
df_covid19_FL.plot(x='totalTestResults',y='positive',kind='scatter',figsize=(15,10))
